# %% [markdown]
# <a href="https://colab.research.google.com/github/MichelleLea26/PBA-carousell-SentimentAnalysis/blob/main/Week%201-Scrap-ReviewCarousellApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Scrapping Carousell App Review**
#
#
#
# > Google Play Link:https://play.google.com/store/apps/details?id=com.thecarousell.Carousell&pcampaignid=web_share
# Application id: com.thecarousell.Carousell

# %% [markdown]
# **Setup & Import**

# %%
# !pip install google_play_scraper
# !pip install textblob
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.3)

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import seaborn as sns
import textblob

# %% [markdown]
# **Scrapping Data**

# %%
#Android App Carousell link from Google Play at
#https://play.google.com/store/apps/details?id=com.thecarousell.Carousell&pcampaignid=web_share
#The apps ID found in the link after id=com.thecarousell.Carousell
#The apps name on Google Play titled: Carousell: Jual Beli dalam App
#Dated 11 March 2026: number of reviews 364k

from google_play_scraper import app, Sort, reviews_all

carousell_reviews = reviews_all(
    'com.thecarousell.Carousell',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'id'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %% [markdown]
# **Simpan Apps reviews ke dataframe**

# %%
df_carousell = pd.DataFrame(np.array(carousell_reviews),columns=['content'])
df_carousell = df_carousell.join(pd.DataFrame(df_carousell.pop('content').tolist()))
df_carousell.to_csv('carousell_reviews.csv', index=False)
df_carousell.head()
# Out:
#                                reviewId         userName  \
# 0  ef1a0eae-8c5b-42cb-899f-8b50675c5caa  Pengguna Google
# 1  6872e98b-b3d5-4f11-a40f-b936b39554c4  Pengguna Google
# 2  ba4b550d-9a7e-4855-8208-899bc7a1a8ac  Pengguna Google
# 3  3d71ba55-05db-41b4-b03e-572527d94af7  Pengguna Google
# 4  9195c5b3-8beb-42eb-9cb4-05eb99a52de8  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  aku follow 48 seller, tapi ternyata di menu "M...      4              0
# 1  aplikasi nya keren gacor baru upload udah ada ...      5              0
# 2  mau reset password & login di device baru fail...      1              0
# 3                                         rekomended      5              0
# 4                                           Nice app      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0             2.436.14 2026-05-02 04:22:06         None       NaT   2.436.14
# 1              2.449.7 2026-05-01 05:00:14         None       NaT    2.449.7
# 2              2.452.8 2026-05-01 01:30:32         None       NaT    2.452.8
# 3              2.451.8 2026-04-30 15:33:08         None       NaT    2.451.8
# 4              2.451.8 2026-04-30 10:26:10         None       NaT    2.451.8

# %% [markdown]
# **Mengambil sampel Review**

# %%
# Mengambil 300 baris teratas dari dataframe
df_top_300 = df_carousell.head(300)

# Menyimpan hasil potongan ini ke dalam file CSV baru
df_top_300.to_csv('carousell_reviews_top_300.csv', index=False)

# Menampilkan informasi jumlah baris dan kolom untuk memastikan
print("Ukuran data sekarang (Baris, Kolom):", df_top_300.shape)
# Out:
#  '2.10.0' '2.28.0' '2.79.144.127' '2.90.207.184' '2.82.158.135'
#  '2.67.75.75' '2.34.1' '2.80.149.129' '2.74.123.108' '2.95.257.217'
#  '2.70.101.94' '2.94.239.209' '2.77.135.120' '2.71.107.97' '2.81.153.132'
#  '2.83.164.140' '2.51.6.20' '2.73.117.106' '2.7.3' '2.62.0.53'
#  '2.50.179.14' '2.69.93.89' '2.5.3' '2.32.0' '2.60.48.47' '2.64.62.62'
#  '2.66.70.71' '2.27.1' '2.42.115' '2.23.0' '2.55.23.31' '2.45.135'
#  '2.13.0' '2.5.2' '2.21.1' '2.47.155' '2.33.1' '2.1.8' '2.44.130' '2.25.1'
#  '2.12.4' '2.6.0' '2.31.0' '2.17.1' '2.16.0' '2.21.0' '2.7.5' '2.27.0'
#  '2.9.1' '2.33.0' '2.30.0' '2.5.1' '2.19.3' '2.26.0' '2.19.1' '2.25.0'
#  '2.12.2' '2.22.0' '2.14.0' '2.0.3' '2.1.7' '2.8.1' '2.12.0' '2.12.3'
#  '2.11.1' '2.8.0' '2.11.0' '2.7.6' '2.9.0' '2.4.1' '2.7.0' '2.7.1' '2.7.4'
#  '2.1.2' '2.4.0' '2.1.5' '2.3.4' '2.3.0' '2.2.5' '2.2.3' '2.2.1' '2.1.6'
#  '2.1.4' '2.1.1' '2.1.0' '2.0.2' '2.0.1' '2.0.0' '1.9.7' '1.9.6' '1.8.8'
#  '1.8.5' '1.7.1']
# 558

# %%
#Menampilkan dalam bentuk tabel
df_carousell.loc[:,["content","score","thumbsUpCount", "reviewCreatedVersion", "at", "replyContent", "repliedAt"]]
# Out:
#                                                  content  score  \
# 0      aku follow 48 seller, tapi ternyata di menu "M...      4
# 1      aplikasi nya keren gacor baru upload udah ada ...      5
# 2      mau reset password & login di device baru fail...      1
# 3                                             rekomended      5
# 4                                               Nice app      5
# ...                                                  ...    ...
# 21890                                       Bagus sekali      5
# 21891                         Carousell saya suka sekali      5
# 21892                       Menyediakan batu dan permata      5
# 21893                                                Top      5
# 21894                                              Bagus      5
#
#        thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                  0             2.436.14 2026-05-02 04:22:06         None
# 1                  0              2.449.7 2026-05-01 05:00:14         None
# 2                  0              2.452.8 2026-05-01 01:30:32         None
# 3                  0              2.451.8 2026-04-30 15:33:08         None
# 4                  0              2.451.8 2026-04-30 10:26:10         None
# ...              ...                  ...                 ...          ...
# 21890              0                1.8.5 2014-09-09 11:07:50         None
# 21891              0                1.8.5 2014-09-07 22:54:25         None
# 21892              0                1.8.5 2014-09-03 16:58:19         None
# 21893              0                1.7.1 2014-06-25 08:04:27         None
# 21894              0                1.3.0 2013-12-23 12:43:59         None
#
#       repliedAt
# 0           NaT
# 1           NaT
# 2           NaT
# 3           NaT
# 4           NaT
# ...         ...
# 21890       NaT
# 21891       NaT
# 21892       NaT
# 21893       NaT
# 21894       NaT
#
# [21895 rows x 7 columns]
