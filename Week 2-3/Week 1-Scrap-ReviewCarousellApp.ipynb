# %%
# !pip install google_play_scraper
# !pip install textblob
from google_play_scraper import app
import pandas as pd
import numpy as np
import sklearn
import requests
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import seaborn as sns
import textblob
#from wordcloud import WordCloud
from pathlib import Path
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score

import pickle
import re
import time
import datetime                              # access to %%time, for timing individual notebook cells
import os
from PIL import Image
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plt.style.use('seaborn-v0_8')
plt.rcParams["figure.figsize"] = (15,10)
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.0 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.3)

# %%
# !pip install google_play_scraper
# !pip install textblob
from google_play_scraper import app
import pandas as pd
import numpy as np
import sklearn
import requests
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import seaborn as sns
import textblob
#from wordcloud import WordCloud
from pathlib import Path
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score

import pickle
import re
import time
import datetime                              # access to %%time, for timing individual notebook cells
import os
from PIL import Image
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plt.style.use('seaborn-v0_8-deep')
plt.rcParams["figure.figsize"] = (15,10)
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.3)

# %%
#Android App Carousell link from Google Play at
#https://play.google.com/store/apps/details?id=com.thecarousell.Carousell&pcampaignid=web_share
#The apps ID found in the link after id=com.thecarousell.Carousell
#The apps name on Google Play titled: Carousell: Jual Beli dalam App
#Dated 11 March 2026: number of reviews 364k

from google_play_scraper import app, Sort, reviews_all

carousell_reviews = reviews_all(
    'com.thecarousell.Carousell',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'id'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)

# %%
#Save the Apps reviews into dataframe
df_carousell = pd.DataFrame(np.array(carousell_reviews),columns=['content'])
df_carousell = df_carousell.join(pd.DataFrame(df_carousell.pop('content').tolist()))
df_carousell.to_csv('carousell_reviews.csv', index=False)
df_carousell.head()
# Out:
#                                reviewId         userName  \
# 0  3d9fbf0c-ac91-440e-8b0c-c27f33d3eb21  Pengguna Google
# 1  50e706a0-3da5-460d-a077-d8a4623bfc0e  Pengguna Google
# 2  ab3bff87-d887-448a-b9b9-2cb84e8fb76d  Pengguna Google
# 3  9a8da1d2-fed3-4b65-bb45-2c9dc8a3eb33  Pengguna Google
# 4  94c341d9-939a-4424-b0aa-00e6eb0e28c5  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  minimal tambahkan fitur pembayaran suspend sep...      1              0
# 1                                             mantap      5              0
# 2  suka dengan aplikasi ini membantu saya menjual...      5              0
# 3                                                  👍      5              0
# 4                                    Banyak penipuan      1              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0              2.445.7 2026-03-09 22:23:59         None       NaT    2.445.7
# 1                 None 2026-03-09 05:04:20         None       NaT       None
# 2              2.444.6 2026-03-08 23:23:43         None       NaT    2.444.6
# 3              2.444.6 2026-03-08 16:12:41         None       NaT    2.444.6
# 4              2.444.6 2026-03-08 11:08:40         None       NaT    2.444.6

# %%
# Mengambil 300 baris teratas dari dataframe
df_top_300 = df_carousell.head(300)

# Menyimpan hasil potongan ini ke dalam file CSV baru
df_top_300.to_csv('carousell_reviews_top_300.csv', index=False)

# Menampilkan informasi jumlah baris dan kolom untuk memastikan
print("Ukuran data sekarang (Baris, Kolom):", df_top_300.shape)
# Out:
# Ukuran data sekarang (Baris, Kolom): (300, 11)

# %%
print(df_carousell.reviewCreatedVersion.unique())
print(df_carousell.reviewCreatedVersion.nunique())
# Out:
# [None '2.444.6' '2.443.8' '2.440.9' '2.442.8' '2.441.8' '2.439.9'
#  '2.384.9' '2.435.7' '2.409.7' '2.436.14' '2.438.9' '2.437.8' '2.432.8'
#  '2.12.2' '2.22.0' '2.14.0' '2.0.3' '2.1.7' '2.8.1' '2.12.0' '2.12.3'
#  '2.11.1' '2.8.0' '2.11.0' '2.7.6' '2.9.0' '2.4.1' '2.7.0' '2.7.1' '2.7.4'
#  '2.1.2' '2.4.0' '2.1.5' '2.3.4' '2.3.0' '2.2.5' '2.2.3' '2.2.1' '2.1.6'
#  '2.1.4' '2.1.1' '2.1.0' '2.0.2' '2.0.1' '2.0.0' '1.9.7' '1.9.6' '1.8.8'
#  '1.8.5' '1.7.1']
# 550

# %%
#We do not need data for column reviewId, userName, userImage so
#we will show only these column
df_carousell.loc[:,["content","score","thumbsUpCount", "reviewCreatedVersion", "at", "replyContent", "repliedAt"]]
# Out:
#                                                  content  score  \
# 0                                                 mantap      5
# 1      suka dengan aplikasi ini membantu saya menjual...      5
# 2                                                      👍      5
# 3                                        Banyak penipuan      1
# 4                                      bagus apliaksinya      5
# ...                                                  ...    ...
# 21843                                       Bagus sekali      5
# 21844                         Carousell saya suka sekali      5
# 21845                       Menyediakan batu dan permata      5
# 21846                                                Top      5
# 21847                                              Bagus      5
#
#        thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                  0                 None 2026-03-09 05:04:20         None
# 1                  0              2.444.6 2026-03-08 23:23:43         None
# 2                  0              2.444.6 2026-03-08 16:12:41         None
# 3                  0              2.444.6 2026-03-08 11:08:40         None
# 4                  0              2.444.6 2026-03-08 08:26:02         None
# ...              ...                  ...                 ...          ...
# 21843              0                1.8.5 2014-09-09 11:07:50         None
# 21844              0                1.8.5 2014-09-07 22:54:25         None
# 21845              0                1.8.5 2014-09-03 16:58:19         None
# 21846              0                1.7.1 2014-06-25 08:04:27         None
# 21847              0                1.3.0 2013-12-23 12:43:59         None
#
#       repliedAt
# 0           NaT
# 1           NaT
# 2           NaT
# 3           NaT
# 4           NaT
# ...         ...
# 21843       NaT
# 21844       NaT
# 21845       NaT
# 21846       NaT
# 21847       NaT
#
# [21848 rows x 7 columns]

# %%
# !pip install emoji

import numpy as np
import pandas as pd
pd.set_option("display.max_colwidth", 200)
#from pandas_profiling import ProfileReport
import regex
import nltk
import wordcloud
import textblob

from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob

import string
import re
import emoji
# Out:
# Requirement already satisfied: emoji in c:\users\hafidz\anaconda3\envs\rstudio\lib\site-packages (1.7.0)

# %%
#Creating polarity on the column: content (review from the apps) using TextBlob
#Read https://textblob.readthedocs.io/en/dev/quickstart.html

from textblob import TextBlob
df_nhsrev['sentiment_polarity'] = df_nhsrev['content'].apply(lambda x: TextBlob(x).polarity)
df_nhsrev['sentiment_subjective'] = df_nhsrev['content'].apply(lambda x: TextBlob(x).subjectivity)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e3f3cdc5db26> in <cell line: 0>()
#       3
#       4 from textblob import TextBlob
# ----> 5 df_nhsrev['sentiment_polarity'] = df_nhsrev['content'].apply(lambda x: TextBlob(x).polarity)
#       6 df_nhsrev['sentiment_subjective'] = df_nhsrev['content'].apply(lambda x: TextBlob(x).subjectivity)
#
# NameError: name 'df_nhsrev' is not defined

# %%
#df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective","at"]]
df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4efed70a1ea0> in <cell line: 2>()
#       1 #df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective","at"]]
# ----> 2 df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective"]]
#
# NameError: name 'df_nhsrev' is not defined

# %%
#Check number of reviews scores
df_nhsrev['score'].value_counts()
# Out:
# 1    9171
# 5    7000
# 3    2216
# 2    2128
# 4    1928
# Name: score, dtype: int64

# %%
plt.hist(df_nhsrev['score'])
plt.show()

# %%
#DATA PREPROCESSING
# Lower casing

# Change the reviews type to string
df_nhsrev['content'] = df_nhsrev['content'].astype(str)# Before lowercasing
# Before lowercasing
print(df_nhsrev['content'][22442])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f62935f605db> in <cell line: 0>()
#       3
#       4 # Change the reviews type to string
# ----> 5 df_nhsrev['content'] = df_nhsrev['content'].astype(str)# Before lowercasing
#       6 # Before lowercasing
#       7 print(df_nhsrev['content'][22442])
#
# NameError: name 'df_nhsrev' is not defined

# %%
#Lowercase all reviews to see the difference
df_nhsrev['content']= df_nhsrev['content'].apply(lambda x: x.lower())
print(df_nhsrev['content'][22442])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-869bb9ed6044> in <cell line: 0>()
#       1 #Lowercase all reviews to see the difference
# ----> 2 df_nhsrev['content']= df_nhsrev['content'].apply(lambda x: x.lower())
#       3 print(df_nhsrev['content'][22442])
#
# NameError: name 'df_nhsrev' is not defined

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#edited from https://www.tensorscience.com/nlp/sentiment-analysis-tutorial-in-python-classifying-reviews-on-movies-and-products
import string

df_nhsrev['wordCount'] = [len(review.split()) for review in df_nhsrev['content']]

df_nhsrev['uppercaseCharCount'] = [sum(char.isupper() for char in review) \
                              for review in df_nhsrev['content']]

df_nhsrev['specialCharCount'] = [sum(char in string.punctuation for char in review) \
                            for review in df_nhsrev['content']]

# %%
df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective","wordCount","uppercaseCharCount","specialCharCount"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-99d67f57bb21> in <cell line: 0>()
# ----> 1 df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective","wordCount","uppercaseCharCount","specialCharCount"]]
#
# NameError: name 'df_nhsrev' is not defined

# %%
#Removing stopwords
#Using nltk
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize, sent_tokenize
from nltk import FreqDist
from nltk.corpus import stopwords, wordnet
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer


from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

from string import punctuation

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# function to plot most frequent terms
def freq_words(x, terms = 30):
  all_words = ' '.join([text for text in x])
  all_words = all_words.split()

  fdist = FreqDist(all_words)
  words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})

  # selecting top 20 most frequent words
  d = words_df.nlargest(columns="count", n = terms)
  plt.figure(figsize=(20,5))
  ax = sns.barplot(data=d, x= "word", y = "count")
  ax.set(ylabel = 'Count')
  plt.show()

# %%
freq_words(df_nhsrev['content'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e369da04c306> in <cell line: 0>()
# ----> 1 freq_words(df_nhsrev['content'])
#
# NameError: name 'freq_words' is not defined

# %%
#check if there is any special character
alphabet = string.ascii_letters+string.punctuation
print(df_nhsrev.content.str.strip(alphabet).astype(bool).any())

extracted_emojis=[]

def extract_emojis(s):
    expe = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    return expe.findall(s)
    return expe.sub(r'',s)

for y in df_nhsrev['content']:
    #print(str(extract_emojis(y)))
    extracted_emojis.append(str(extract_emojis(y)))

print(extracted_emojis)
# Out:
# True
# ['[]', '[]', '[]', '[]', '[]', '[]', '[]', "['💪']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['🙄']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['👍']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['🎲']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['🗑']", '[]', '[]', '[]', '[]', '[]', "['🙈']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['🕋', '👼', '🏾', '👼', '🏾', '👼', '🏾', '👼', '🏾', '🦁', '👼', '🏾', '👼', '🏾', '👼', '🏻', '💙', '💙', '📱', '🌎', '🔥']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['😤', '😤']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['😒', '😟', '😱', '😱']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['😱']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['😊']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['😪']", '[]', "['🤔']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', "['🙁']", '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[]', '[] ...

# %%
df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective","wordCount","uppercaseCharCount","specialCharCount"]]
# Out:
#                                                                                                                                                                                                        content  \
# 0      pointless... absolutely pointless is what this app has unfortunately become. it doesn't trace people you're physically near to anymore or anything of the sort, so you'd be none the wiser if you we...
# 1                                                                                                                                                                                      easy to use once set up
# 2                                                                                                                                                                                from health care and covid-19
# 3                                                            had half a notification this morning then it disappeared spent all day trying to find it. no idea what i'm supposed to do now apart from worrying
# 4                                                                                                                                                                                easy to use and fast response
# ...                                                                                                                                                                                                        ...
# 22438  tells me is installed but not on phone. can't get as far as putting the code i have been given in. doesn't inspire confidence. it eventually downloaded and the code works. this needs to be slicker...
# 22439  the emails from the nhs could do a better job of highlighting the access codes, since they do waffle on quite a bit and we're all busy. assuming you did read your email carefully and collected the...
# 22440                                                 seems to work really well. super simple setup. people stop giving it 1* because you don't have a signup code. that is not what the rating system is for.
# 22441                                                                                                                                                                    not able to install ,code didn't work
# 22442                                                                                                                                                    where can i get a code? the instructions is not clear
#
#        score  sentiment_polarity  sentiment_subjective  wordCount  \
# 0          1           -0.060000              0.680000         59
# 1          5            0.433333              0.833333          6
# 2          5            0.000000              0.000000          5
# 3          1           -0.133333              0.133333         27
# 4          5            0.316667              0.716667          6
# ...      ...                 ...                   ...        ...
# 22438      3            0.100000              1.000000         55
# 22439      4            0.346667              0.591667         51
# 22440      5            0.177778              0.407937         29
# 22441      1           -0.250000              0.625000          7
# 22442      2           -0.050000              0.383333         11
#
#        uppercaseCharCount  specialCharCount
# 0                       0                12
# 1                       0                 0
# 2                       0                 1
# 3                       0                 2
# 4                       0                 0
# ...                   ...               ...
# 22438                   0                10
# 22439                   0                 7
# 22440                   0                 6
# 22441                   0                 2
# 22442                   0                 1
#
# [22443 rows x 7 columns]

# %%
#Add a column name polarity_rating from changing the score of the review into 3 labels: Pos, Negative Neutral
df_nhsrev['sentiment_rating'] = df_nhsrev['score'].apply(lambda x: 'Positive' if x > 3 else('Neutral' if x == 3  else 'Negative'))

# %%
df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective","sentiment_rating"]]
# Out:
#                                                                                                                                                                                                        content  \
# 0      pointless... absolutely pointless is what this app has unfortunately become. it doesn't trace people you're physically near to anymore or anything of the sort, so you'd be none the wiser if you we...
# 1                                                                                                                                                                                      easy to use once set up
# 2                                                                                                                                                                                from health care and covid-19
# 3                                                            had half a notification this morning then it disappeared spent all day trying to find it. no idea what i'm supposed to do now apart from worrying
# 4                                                                                                                                                                                easy to use and fast response
# ...                                                                                                                                                                                                        ...
# 22438  tells me is installed but not on phone. can't get as far as putting the code i have been given in. doesn't inspire confidence. it eventually downloaded and the code works. this needs to be slicker...
# 22439  the emails from the nhs could do a better job of highlighting the access codes, since they do waffle on quite a bit and we're all busy. assuming you did read your email carefully and collected the...
# 22440                                                 seems to work really well. super simple setup. people stop giving it 1* because you don't have a signup code. that is not what the rating system is for.
# 22441                                                                                                                                                                    not able to install ,code didn't work
# 22442                                                                                                                                                    where can i get a code? the instructions is not clear
#
#        score  sentiment_polarity  sentiment_subjective sentiment_rating
# 0          1           -0.060000              0.680000         Negative
# 1          5            0.433333              0.833333         Positive
# 2          5            0.000000              0.000000         Positive
# 3          1           -0.133333              0.133333         Negative
# 4          5            0.316667              0.716667         Positive
# ...      ...                 ...                   ...              ...
# 22438      3            0.100000              1.000000          Neutral
# 22439      4            0.346667              0.591667         Positive
# 22440      5            0.177778              0.407937         Positive
# 22441      1           -0.250000              0.625000         Negative
# 22442      2           -0.050000              0.383333         Negative
#
# [22443 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 10))
sns.scatterplot(df_nhsrev['sentiment_polarity'], df_nhsrev['sentiment_subjective'],
                hue = df_nhsrev['sentiment_rating'], edgecolor='white', palette="pastel")
plt.title("Google Play Store NHS Track and Trace Reviews Sentiment Analysis", fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d1924b086c1e> in <cell line: 0>()
#       2 import seaborn as sns
#       3 plt.figure(figsize=(15, 10))
# ----> 4 sns.scatterplot(df_nhsrev['sentiment_polarity'], df_nhsrev['sentiment_subjective'],
#       5                 hue = df_nhsrev['sentiment_rating'], edgecolor='white', palette="pastel")
#       6 plt.title("Google Play Store NHS Track and Trace Reviews Sentiment Analysis", fontsize=20)
#
# NameError: name 'df_nhsrev' is not defined

# %%
#Print the extracted emojis review column (content) before stopwords
df_nhsrev.to_csv(r'C:\Users\Hafidz\PhDwork\APPREV\df_nhsrev_before_stopwords_sentiment_rating.csv', index = False)

# %%
import nltk
from nltk.corpus import stopwords
stop = stopwords.words('english') + ["someone","still","would","need"]
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'someone', 'still', 'would', 'need']

# %%
print(len(stop))
# Out:
# 183

# %%
df_nhsrev_stopwords = df_nhsrev.loc[:,["content","score","sentiment_polarity", "sentiment_subjective","sentiment_rating"]]

# %%
# Exclude stopwords
df_nhsrev_stopwords['tweet_without_stopwords'] = df_nhsrev_stopwords['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
print(df_nhsrev_stopwords)
# Out:
#                                                                                                                                                                                                        content  \
# 0      pointless... absolutely pointless is what this app has unfortunately become. it doesn't trace people you're physically near to anymore or anything of the sort, so you'd be none the wiser if you we...
# 1                                                                                                                                                                                      easy to use once set up
# 2                                                                                                                                                                                from health care and covid-19
# 3                                                            had half a notification this morning then it disappeared spent all day trying to find it. no idea what i'm supposed to do now apart from worrying
# 4                                                                                                                                                                                easy to use and fast response
# ...                                                                                                                                                                                                        ...
# 22438  tells me is installed but not on phone. can't get as far as putting the code i have been given in. doesn't inspire confidence. it eventually downloaded and the code works. this needs to be slicker...
# 22439  the emails from the nhs could do a better job of highlighting the access codes, since they do waffle on quite a bit and we're all busy. assuming you did read your email carefully and collected the...
# 22440                                                 seems to work really well. super simple setup. people stop giving it 1* because you don't have a signup code. that is not what the rating system is for.
# 22441                                                                                                                                                                    not able to install ,code didn't work
# 22442                                                                                                                                                    where can i get a code? the instructions is not clear
#
#        score  sentiment_polarity  sentiment_subjective sentiment_rating  \
# 0          1           -0.060000              0.680000         Negative
# 1          5            0.433333              0.833333         Positive
# 2          5            0.000000              0.000000         Positive
# 3          1           -0.133333              0.133333         Negative
# 4          5            0.316667              0.716667         Positive
# ...      ...                 ...                   ...              ...
# 22438      3            0.100000              1.000000          Neutral
# 22439      4            0.346667              0.591667         Positive
# 22440      5            0.177778              0.407937         Positive
# 22441      1           -0.250000              0.625000         Negative
# 22442      2           -0.050000              0.383333         Negative
#
#                                                                                                                                                                                        tweet_without_stopwords
# 0      pointless... absolutely pointless app unfortunately become. trace people physically near anymore anything sort, none wiser talking closely covid-positive case 15+ minutes. tells rules place use ve...
# 1                                                                                                                                                                                                 easy use set
# 2                                                                                                                                                                                         health care covid-19
# 3                                                                                                             half notification morning disappeared spent day trying find it. idea i'm supposed apart worrying
# 4                                                                                                                                                                                       easy use fast response
# ...                                                                                                                                                                                                        ...
# 22438     tells installed phone. can't get far putting code given in. inspire confidence. eventually downloaded code works. needs slicker quicker people going use it...people expect get app use immediately.
# 22439             emails nhs could better job highlighting access codes, since waffle quite bit we're busy. assuming read email carefully collected one-time code, app seems work nicely. visual design great.
# 22440                                                                                                        seems work really well. super simple setup. people stop giving 1* signup code. rating system for.
# 22441                                                                                                                                                                                  able install ,code work
# 22442                                                                                                                                                                             get code? instructions clear
#
# [22443 rows x 6 columns]

# %%
pat = r'\b(?:{})\b'.format('|'.join(stop))
df_nhsrev_stopwords['tweet_without_stopwords'] = df_nhsrev_stopwords['content'].str.replace(pat, '')
df_nhsrev_stopwords['tweet_without_stopwords'] = df_nhsrev_stopwords['tweet_without_stopwords'].str.replace(r'\s+', ' ')
# Out:
# C:\Users\Hafidz\anaconda3\envs\rstudio\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# C:\Users\Hafidz\anaconda3\envs\rstudio\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Save into csv after applying stopwords
df_nhsrev_stopwords.to_csv(r'C:\Users\Hafidz\PhDwork\APPREV\df_nhsrev_after_stopwords_sentiment_rating2.csv', index = False)

# %%
#Count after stopwords
#edited from https://www.tensorscience.com/nlp/sentiment-analysis-tutorial-in-python-classifying-reviews-on-movies-and-products
import string

df_nhsrev_stopwords['wordCount'] = [len(review.split()) for review in df_nhsrev_stopwords['content']]
df_nhsrev_stopwords['wordCount_after_stopwords'] = [len(review.split()) for review in df_nhsrev_stopwords['tweet_without_stopwords']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7553fa35fcc7> in <cell line: 0>()
#       3 import string
#       4
# ----> 5 df_nhsrev_stopwords['wordCount'] = [len(review.split()) for review in df_nhsrev_stopwords['content']]
#       6 df_nhsrev_stopwords['wordCount_after_stopwords'] = [len(review.split()) for review in df_nhsrev_stopwords['tweet_without_stopwords']]
#
# NameError: name 'df_nhsrev_stopwords' is not defined

# %%
df_nhsrev_stopwords.loc[:,["content","score","sentiment_polarity", "sentiment_rating","wordCount","tweet_without_stopwords", "wordCount_after_stopwords"]]
# Out:
#                                                                                                                                                                                                        content  \
# 0      pointless... absolutely pointless is what this app has unfortunately become. it doesn't trace people you're physically near to anymore or anything of the sort, so you'd be none the wiser if you we...
# 1                                                                                                                                                                                      easy to use once set up
# 2                                                                                                                                                                                from health care and covid-19
# 3                                                            had half a notification this morning then it disappeared spent all day trying to find it. no idea what i'm supposed to do now apart from worrying
# 4                                                                                                                                                                                easy to use and fast response
# ...                                                                                                                                                                                                        ...
# 22438  tells me is installed but not on phone. can't get as far as putting the code i have been given in. doesn't inspire confidence. it eventually downloaded and the code works. this needs to be slicker...
# 22439  the emails from the nhs could do a better job of highlighting the access codes, since they do waffle on quite a bit and we're all busy. assuming you did read your email carefully and collected the...
# 22440                                                 seems to work really well. super simple setup. people stop giving it 1* because you don't have a signup code. that is not what the rating system is for.
# 22441                                                                                                                                                                    not able to install ,code didn't work
# 22442                                                                                                                                                    where can i get a code? the instructions is not clear
#
#        score  sentiment_polarity sentiment_rating  wordCount  \
# 0          1           -0.060000         Negative         59
# 1          5            0.433333         Positive          6
# 2          5            0.000000         Positive          5
# 3          1           -0.133333         Negative         27
# 4          5            0.316667         Positive          6
# ...      ...                 ...              ...        ...
# 22438      3            0.100000          Neutral         55
# 22439      4            0.346667         Positive         51
# 22440      5            0.177778         Positive         29
# 22441      1           -0.250000         Negative          7
# 22442      2           -0.050000         Negative         11
#
#                                                                                                                                                                                        tweet_without_stopwords  \
# 0      pointless... absolutely pointless app unfortunately become. ' trace people ' physically near anymore anything sort, ' none wiser talking closely covid-positive case 15+ minutes. tells rules place ...
# 1                                                                                                                                                                                                easy use set
# 2                                                                                                                                                                                         health care covid-19
# 3                                                                                                                 half notification morning disappeared spent day trying find . idea ' supposed apart worrying
# 4                                                                                                                                                                                       easy use fast response
# ...                                                                                                                                                                                                        ...
# 22438           tells installed phone. ' get far putting code given . ' inspire confidence. eventually downloaded code works. needs slicker quicker people going use ...people expect get app use immediately.
# 22439                 emails nhs could better job highlighting access codes, since waffle quite bit ' busy. assuming read email carefully collected one-time code, app seems work nicely. visual design great.
# 22440                                                                                                         seems work really well. super simple setup. people stop giving 1* ' signup code. rating system .
# 22441                                                                                                                                                                                able install ,code ' work
# 22442                                                                                                                                                                             get code? instructions clear
#
#        wordCount_after_stopwords
# 0                             30
# 1                              3
# 2                              3
# 3                             14
# 4                              4
# ...                          ...
# 22438                         29
# 22439                         28
# 22440                         17
# 22441                          5
# 22442                          4
#
# [22443 rows x 7 columns]

# %%
# function to plot most frequent terms
def freq_words(x, terms = 30):
  all_words = ' '.join([text for text in x])
  all_words = all_words.split()

  fdist = FreqDist(all_words)
  words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})

  # selecting top 20 most frequent words
  d = words_df.nlargest(columns="count", n = terms)
  plt.figure(figsize=(20,5))
  ax = sns.barplot(data=d, x= "word", y = "count")
  ax.set(ylabel = 'Count')
  plt.show()

# %%
freq_words(df_nhsrev_stopwords['tweet_without_stopwords'])

# %%
newStopWords = ["'",".",",", "someone","still","would","need"]

#from nltk.corpus import stopwords
#stoplist = stopwords.words('english') + ['though']

#NOT YET DONE ==== 24 May 2022

# %%
#Stemming

#Stemming function chops off the end of the word
#and transform the word into its root form.
#All suffixes like -s, -es, -ed, -ing are removed.

def stemming(x):
    st = PorterStemmer()
    if x is not None:
       for word in x.split():
           st.stem(word)

df_nhsrev_stopwords['tweet_without_stopwords'].apply(lambda x:stemming(x))
print(df_nhsrev_stopwords['tweet_without_stopwords'][22439])
# Out:
#  emails nhs could better job highlighting access codes, since waffle quite bit ' busy. assuming read email carefully collected one-time code, app seems work nicely. visual design great.

# %%
#===BIGRAM https://towardsdatascience.com/text-analysis-basics-in-python-443282942ec5 not yet
#Creating bigram/trigram to search

# %%
#DROP NA
df_nhsrev_stopwords.dropna(inplace=True)
df_nhsrev_stopwords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22443 entries, 0 to 22442
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   content                    22443 non-null  object
#  1   score                      22443 non-null  int64
#  2   sentiment_polarity         22443 non-null  float64
#  3   sentiment_subjective       22443 non-null  float64
#  4   sentiment_rating           22443 non-null  object
#  5   tweet_without_stopwords    22443 non-null  object
#  6   wordCount                  22443 non-null  int64
#  7   wordCount_after_stopwords  22443 non-null  int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.5+ MB

# %%
df_nhsrev_stopwords.loc[:,["content","score","sentiment_rating","wordCount","tweet_without_stopwords", "wordCount_after_stopwords"]]
# Out:
#                                                                                                                                                                                                        content  \
# 0      pointless... absolutely pointless is what this app has unfortunately become. it doesn't trace people you're physically near to anymore or anything of the sort, so you'd be none the wiser if you we...
# 1                                                                                                                                                                                      easy to use once set up
# 2                                                                                                                                                                                from health care and covid-19
# 3                                                            had half a notification this morning then it disappeared spent all day trying to find it. no idea what i'm supposed to do now apart from worrying
# 4                                                                                                                                                                                easy to use and fast response
# ...                                                                                                                                                                                                        ...
# 22438  tells me is installed but not on phone. can't get as far as putting the code i have been given in. doesn't inspire confidence. it eventually downloaded and the code works. this needs to be slicker...
# 22439  the emails from the nhs could do a better job of highlighting the access codes, since they do waffle on quite a bit and we're all busy. assuming you did read your email carefully and collected the...
# 22440                                                 seems to work really well. super simple setup. people stop giving it 1* because you don't have a signup code. that is not what the rating system is for.
# 22441                                                                                                                                                                    not able to install ,code didn't work
# 22442                                                                                                                                                    where can i get a code? the instructions is not clear
#
#        score sentiment_rating  wordCount  \
# 0          1         Negative         59
# 1          5         Positive          6
# 2          5         Positive          5
# 3          1         Negative         27
# 4          5         Positive          6
# ...      ...              ...        ...
# 22438      3          Neutral         55
# 22439      4         Positive         51
# 22440      5         Positive         29
# 22441      1         Negative          7
# 22442      2         Negative         11
#
#                                                                                                                                                                                        tweet_without_stopwords  \
# 0      pointless... absolutely pointless app unfortunately become. ' trace people ' physically near anymore anything sort, ' none wiser talking closely covid-positive case 15+ minutes. tells rules place ...
# 1                                                                                                                                                                                                easy use set
# 2                                                                                                                                                                                         health care covid-19
# 3                                                                                                                 half notification morning disappeared spent day trying find . idea ' supposed apart worrying
# 4                                                                                                                                                                                       easy use fast response
# ...                                                                                                                                                                                                        ...
# 22438           tells installed phone. ' get far putting code given . ' inspire confidence. eventually downloaded code works. needs slicker quicker people going use ...people expect get app use immediately.
# 22439                 emails nhs could better job highlighting access codes, since waffle quite bit ' busy. assuming read email carefully collected one-time code, app seems work nicely. visual design great.
# 22440                                                                                                         seems work really well. super simple setup. people stop giving 1* ' signup code. rating system .
# 22441                                                                                                                                                                                able install ,code ' work
# 22442                                                                                                                                                                             get code? instructions clear
#
#        wordCount_after_stopwords
# 0                             30
# 1                              3
# 2                              3
# 3                             14
# 4                              4
# ...                          ...
# 22438                         29
# 22439                         28
# 22440                         17
# 22441                          5
# 22442                          4
#
# [22443 rows x 6 columns]
